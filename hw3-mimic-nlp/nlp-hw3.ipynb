# %% [markdown]
# # MIMIC NLP HW3
#
# ## GitHub repo file link:
#
# https://github.com/UT-Austin-MSAI-Program/ai-in-healthcare-ai395t/blob/main/module-6/nlp-hw3.ipynb
#
# ## Setup

# %%
# %pip install -U pip setuptools wheel
# %pip install spacy==3.7.5
# %pip install gensim
# %pip install transformers

import spacy
from spacy import displacy # Entity Visualizer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import os

# !python3 -m spacy download en_core_web_md
# Out:
# Requirement already satisfied: pip in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (25.0.1)
# Requirement already satisfied: setuptools in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (75.8.0)
# Requirement already satisfied: wheel in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (0.45.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: spacy==3.7.5 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (3.0.6)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (0.3.4)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (0.3.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (1.8.2)
# Requirement already satisfied: jinja2 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (3.1.5)
# Requirement already satisfied: setuptools in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (75.8.0)
# Requirement already satisfied: packaging>=20.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy==3.7.5) (1.26.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.5) (4.12.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.5) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.5) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.5) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy==3.7.5) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy==3.7.5) (0.1.4)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy==3.7.5) (7.1.2)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy==3.7.5) (0.16.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy==3.7.5) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from jinja2->spacy==3.7.5) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gensim in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from gensim) (5.2.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: transformers in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (4.49.0)
# Requirement already satisfied: filelock in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from requests->transformers) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# Collecting en-core-web-md==3.7.1
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.7.1/en_core_web_md-3.7.1-py3-none-any.whl (42.8 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from en-core-web-md==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.6)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.3.4)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.3.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.8.2)
# Requirement already satisfied: jinja2 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.1.5)
# Requirement already satisfied: setuptools in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (75.8.0)
# Requirement already satisfied: packaging>=20.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.26.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.12.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.1.4)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (7.1.2)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.16.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
MIMIC_3_DIR = '../mimic/mimic-iii-clinical-database-1.4'
os.chdir(MIMIC_3_DIR)

# Load diagnosis & notes data
diagnosis_df = pd.read_csv('DIAGNOSES_ICD.csv').set_index('ROW_ID')
notes_df = pd.read_csv('NOTEEVENTS.csv', low_memory=False).set_index('ROW_ID')

# %% [markdown]
# # Target Infections

# %%
# Create a dataframe with only discharge summaries
discharge_summaries_df = notes_df.loc[notes_df['CATEGORY'] == 'Discharge summary', ['SUBJECT_ID', 'HADM_ID', 'TEXT']]

# discharge_summaries_df.head()

# Common infection codes
infection_codes = ['0380', '03810', '0382', '0383', '03842', '03843']
# Filter for only infection codes
infection_df = diagnosis_df[diagnosis_df['ICD9_CODE'].isin(infection_codes)].copy()

infection_types = {   
    "0380": "Streptococcal septicemia",
    "03810": "Staphylococcal septicemia, unspecified",
    "0382": "Pneumococcal septicemia [Streptococcus pneumoniae septicemia]",
    "0383": "Septicemia due to anaerobes",
    "03842": "Septicemia due to escherichia coli [E. coli]",
    "03843": "Septicemia due to pseudomonas",
}

# Map infection types to infection codes
infection_df['INFECTION_TYPE'] = infection_df['ICD9_CODE'].map(infection_types)

# %%
# Merge infection data with discharge summaries
discharge_summaries_df = pd.merge(discharge_summaries_df, infection_df, on='HADM_ID', how='inner')
# Drop duplicates
discharge_summaries_df.drop_duplicates(subset='HADM_ID', inplace=True)

discharge_summaries_df['INFECTION_TYPE'].value_counts()
# Out:
# INFECTION_TYPE
# Septicemia due to escherichia coli [E. coli]                     455
# Streptococcal septicemia                                         353
# Septicemia due to pseudomonas                                    116
# Septicemia due to anaerobes                                      106
# Pneumococcal septicemia [Streptococcus pneumoniae septicemia]     85
# Staphylococcal septicemia, unspecified                            43
# Name: count, dtype: int64

# %% [markdown]
# # Tokenization & Entity Extraction

# %%
# Load specified model (spacy/scispacy)
def load_nlp_model(model_name="en_core_web_md"): # Default spacy
    try:
        return spacy.load(model_name) # Loads specified model.
    except OSError:
        raise ValueError(f"Could not load model '{model_name}'. Make sure it is installed.")

# Tokenization function (supports both spaCy & SciSpaCy)
def tokenize_text(text, model_name="en_core_web_md"):
    nlp = load_nlp_model(model_name) # Loads specified model
    doc = nlp(text)
    
    tokens = [
        token.text.lower() # Lowercasing tokens
        for token in doc
        # Removing stopwords, punctuation, and keeping only words and numbers
        if (token.is_alpha or token.is_digit) and not token.is_stop and not token.is_punct
    ]
    
    return " ".join(tokens)

# Named Entity Recognition (NER) function
def extract_entities(text, model_name="en_core_web_md"):
    nlp = load_nlp_model(model_name)
    doc = nlp(text)
    # Extracts named entities from text using the specified NLP model
    entities = [(ent.text, ent.start_char, ent.end_char, ent.label_) for ent in doc.ents]
    # Returns a list of (text, start_char, end_char, label) tuples
    return entities

# %% [markdown]
# # Spacy Named Entity Recognition (NER)

# %%
spacy_nlp = load_nlp_model("en_core_web_md")

# Get E. coli infection discharge summaries
ecoli_df = discharge_summaries_df[discharge_summaries_df['ICD9_CODE'] == '03842']

# Preprocess text for E. coli infection discharge summaries using spacy
ecoli_df['SPACY_PROCESSED_TEXT'] = ecoli_df['TEXT'].apply(lambda text: tokenize_text(text, "en_core_web_md"))

# Extract entities from E. coli infection df's first discharge summary
entities = extract_entities(ecoli_df.iloc[0]['SPACY_PROCESSED_TEXT'], "en_core_web_md")

# Print entities
for entity in entities:
    print(entity)
# Out:
# /var/folders/wd/pkw1ts416gsg2fjyp1rgznqc0000gn/T/ipykernel_99933/714388519.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ecoli_df['SPACY_PROCESSED_TEXT'] = ecoli_df['TEXT'].apply(lambda text: tokenize_text(text, "en_core_web_md"))
# ('2194', 15, 19, 'CARDINAL')
# ('7', 22, 23, 'CARDINAL')
# ('2194', 39, 43, 'CARDINAL')
# ('2 2', 44, 47, 'CARDINAL')
# ('290', 121, 124, 'CARDINAL')
# ('age 90', 233, 239, 'DATE')
# ('russian', 242, 249, 'NORP')
# ('ems', 319, 322, 'ORG')
# ('101 bp', 396, 402, 'QUANTITY')
# ('20 98', 406, 411, 'CARDINAL')
# ('4 l ns vanco 1 g', 454, 470, 'QUANTITY')
# ('1 g', 486, 489, 'QUANTITY')
# ('500 mg', 500, 506, 'QUANTITY')
# ('mg ativan 2 mg', 519, 533, 'PRODUCT')
# ('153', 582, 585, 'CARDINAL')
# ('10 day', 596, 602, 'DATE')
# ('7 day', 643, 648, 'DATE')
# ('90', 941, 943, 'CARDINAL')
# ('brady', 1008, 1013, 'PERSON')
# ('4', 1030, 1031, 'CARDINAL')
# ('sec', 1032, 1035, 'ORG')
# ('micu micu', 1097, 1106, 'PERSON')
# ('1', 1150, 1151, 'CARDINAL')
# ('2', 1217, 1218, 'CARDINAL')
# ('17', 1251, 1253, 'CARDINAL')
# ('micu', 1254, 1258, 'GPE')
# ('1', 1273, 1274, 'CARDINAL')
# ('2', 1315, 1316, 'CARDINAL')
# ('3', 1403, 1404, 'CARDINAL')
# ('400 mg po', 1444, 1453, 'MONEY')
# ('daily', 1454, 1459, 'DATE')
# ('7 days', 1464, 1470, 'DATE')
# ('8 23', 1623, 1627, 'CARDINAL')
# ('progression treated cytoxan velban', 1628, 1662, 'ORG')
# ('10 28', 1866, 1871, 'CARDINAL')
# ('4 mg', 1924, 1928, 'QUANTITY')
# ('1 27', 1940, 1944, 'CARDINAL')
# ('50 mg', 1958, 1963, 'MONEY')
# ('velban', 1980, 1986, 'ORG')
# ('ni', 2351, 2353, 'PERSON')
# ('79 bp', 2600, 2605, 'QUANTITY')
# ('nc heent', 2616, 2624, 'PERSON')
# ('sclera anicteric', 2625, 2641, 'PERSON')
# ('2', 2670, 2671, 'CARDINAL')
# ('abd', 2775, 2778, 'PERSON')
# ('1 2 mm', 2973, 2979, 'QUANTITY')
# ('24 94', 3153, 3158, 'DATE')
# ('2', 3314, 3315, 'CARDINAL')
# ('abd', 3433, 3436, 'PERSON')
# ('3 4 mm', 3635, 3641, 'QUANTITY')
# ('micu', 3735, 3739, 'GPE')
# ('102', 3754, 3757, 'CARDINAL')
# ('31 94', 3761, 3766, 'DATE')
# ('heent perrl eomi anicteric tachy mm op', 3841, 3879, 'PERSON')
# ('1 8', 4242, 4245, 'CARDINAL')
# ('1 10', 4373, 4377, 'CARDINAL')
# ('3', 4660, 4661, 'CARDINAL')
# ('2193', 4899, 4903, 'GPE')
# ('12 22', 5129, 5134, 'CARDINAL')
# ('age 90', 5173, 5179, 'DATE')
# ('2194', 5362, 5366, 'CARDINAL')
# ('1 21', 5367, 5371, 'CARDINAL')
# ('dnr dni', 5380, 5387, 'PERSON')
# ('2194', 5491, 5495, 'CARDINAL')
# ('1 30', 5496, 5500, 'CARDINAL')
# ('2194', 5604, 5608, 'CARDINAL')
# ('2 2', 5609, 5612, 'CARDINAL')
# ('150', 5685, 5688, 'CARDINAL')
# ('4 second', 5762, 5770, 'TIME')
# ('40', 5790, 5792, 'CARDINAL')
# ('micu pt', 5857, 5864, 'GPE')
# ('1 30', 5940, 5944, 'CARDINAL')
# ('20 seconds', 5969, 5979, 'TIME')
# ('3', 6129, 6130, 'CARDINAL')
# ('1', 6141, 6142, 'CARDINAL')
# ('1', 6148, 6149, 'CARDINAL')
# ('10', 6180, 6182, 'CARDINAL')
# ('10', 6242, 6244, 'CARDINAL')
# ('1', 6256, 6257, 'CARDINAL')
# ('1 25', 6283, 6287, 'CARDINAL')
# ('prbc', 6306, 6310, 'GPE')
# ('24', 6328, 6330, 'CARDINAL')
# ('2194', 6343, 6347, 'CARDINAL')
# ('1 12', 6348, 6352, 'CARDINAL')
# ('250 cc', 6445, 6451, 'QUANTITY')
# ('vanc piptaz', 6837, 6848, 'PERSON')
# ('1 22', 6857, 6861, 'CARDINAL')
# ('1 24', 6958, 6962, 'CARDINAL')
# ('gnr', 6963, 6966, 'PERSON')
# ('148 150', 7037, 7044, 'CARDINAL')
# ('defecit', 7056, 7063, 'ORG')
# ('po intake', 7092, 7101, 'PERSON')
# ('2 22', 7201, 7205, 'CARDINAL')
# ('1 l ns', 7472, 7478, 'QUANTITY')
# ('2194', 7615, 7619, 'CARDINAL')
# ('1 30', 7620, 7624, 'CARDINAL')
# ('100', 7665, 7668, 'CARDINAL')
# ('po intake diuresis', 8170, 8188, 'PERSON')
# ('1 9 positive pt', 8319, 8334, 'DATE')
# ('ceftazidime days', 8364, 8380, 'DATE')
# ('1 19', 8397, 8401, 'CARDINAL')
# ('1 22', 8432, 8436, 'DATE')
# ('diurese', 8901, 8908, 'NORP')
# ('micu development', 8909, 8925, 'ORG')
# ('2194', 8988, 8992, 'CARDINAL')
# ('1 17', 8993, 8997, 'CARDINAL')
# ('1 20', 9008, 9012, 'CARDINAL')
# ('retic', 9157, 9162, 'NORP')
# ('1', 9336, 9337, 'CARDINAL')
# ('100 mg 3', 9383, 9391, 'QUANTITY')
# ('4', 9415, 9416, 'CARDINAL')
# ('325 mg', 9472, 9478, 'QUANTITY')
# ('6', 9485, 9486, 'CARDINAL')
# ('3 300 30 mg qid prn 7', 9503, 9524, 'QUANTITY')
# ('12', 9628, 9630, 'CARDINAL')
# ('1', 9665, 9666, 'CARDINAL')
# ('2', 9702, 9703, 'CARDINAL')
# ('3', 9758, 9759, 'CARDINAL')
# ('1 mg po', 9771, 9778, 'MONEY')
# ('daily', 9779, 9784, 'DATE')
# ('daily', 9810, 9815, 'DATE')
# ('1 neb ih 6', 9842, 9852, 'QUANTITY')
# ('tab po', 9895, 9901, 'PERSON')
# ('8', 9919, 9920, 'CARDINAL')
# ('100 mg po', 9937, 9946, 'QUANTITY')
# ('9 albuterol neb soln', 9951, 9971, 'MONEY')
# ('1 neb ih prn', 9972, 9984, 'QUANTITY')
# ('10', 10000, 10002, 'CARDINAL')
# ('500 mg', 10024, 10030, 'QUANTITY')
# ('11', 10034, 10036, 'CARDINAL')
# ('25 mcg hr', 10052, 10061, 'QUANTITY')
# ('12', 10065, 10067, 'CARDINAL')
# ('5', 10078, 10079, 'CARDINAL')
# ('1', 10086, 10087, 'CARDINAL')
# ('12 hours', 10119, 10127, 'TIME')
# ('13', 10135, 10137, 'CARDINAL')
# ('1', 10151, 10152, 'CARDINAL')
# ('2194', 10269, 10273, 'CARDINAL')
# ('2 2', 10274, 10277, 'CARDINAL')
# ('2194', 10436, 10440, 'CARDINAL')
# ('2 2', 10441, 10444, 'CARDINAL')
# ('2194', 10484, 10488, 'CARDINAL')
# ('2 2', 10489, 10492, 'CARDINAL')
# ('2194', 10531, 10535, 'CARDINAL')
# ('md md md 292', 10549, 10561, 'GPE')

# %%
# Visualize entities in the first discharge summary PROCESSED_TEXT
doc = spacy_nlp(ecoli_df['SPACY_PROCESSED_TEXT'].iloc[0])
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">admission date
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2194
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  1
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  discharge date
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2194
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2 2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  service medicine allergies patient recorded having known allergies drugs
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     290
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  chief complaint altered mental status hypotension major surgical invasive procedure history present illness
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     age 90
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  f
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  speaking h o refractory nodular sclerosing hodgkins lymphoma brought
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ems
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  admitted home health care aide noted hypotensive confused ed t rectal hr
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     101 bp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  rr
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20 98
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  incontinant guaiac positive stool treated
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4 l ns vanco 1 g
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  iv ceftazadime
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1 g
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  iv flagyl
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500 mg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  iv received
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mg ativan 2 mg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  iv morphine agitation pt admitted hospital unit
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     153
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  completed
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  course ceftazadime vancomycin urosepsis
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7 day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  course metronidazole completed empiric treatment diff given loose stools setting elevated wbc count diff assays negative pt stabilized transferred floor care time transfer active issues poor nutritional status thrombocytopenia anemia floor pt experienced episode new afib rvr hypotension sbp
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     90
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  respiratory distress received fluid resuscitation concern tachy
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     brady
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  syndrome pauses
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sec
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  telemetry ep curbside felt digoxin recommended pt readmitted
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     micu micu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  started vancomycin piperacillin tazobactam
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; bor

# %% [markdown]
# # SciSpacy Named Entity Recognition (NER)

# %%
# Load a biomedical NLP model
scispacy_nlp = load_nlp_model("en_core_sci_md")

# Preprocess text for Ecoli infection discharge summaries using scispacy
ecoli_df['SCISPACY_PROCESSED_TEXT'] = ecoli_df['TEXT'].apply(lambda text: tokenize_text(text, "en_core_sci_md"))

# Use scispacy to extract entities from the first discharge summary
entities = extract_entities(ecoli_df.iloc[0]['SCISPACY_PROCESSED_TEXT'], "en_core_sci_md")

# Print entities
for entity in entities:
    print(entity)
# Out:
# /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages/spacy/language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]
# /var/folders/wd/pkw1ts416gsg2fjyp1rgznqc0000gn/T/ipykernel_99933/2048765605.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ecoli_df['SCISPACY_PROCESSED_TEXT'] = ecoli_df['TEXT'].apply(lambda text: tokenize_text(text, "en_core_sci_md"))
# ('admission', 0, 9, 'ENTITY')
# ('discharge', 24, 33, 'ENTITY')
# ('service medicine', 48, 64, 'ENTITY')
# ('patient', 75, 82, 'ENTITY')
# ('allergies drugs', 105, 120, 'ENTITY')
# ('chief complaint', 125, 140, 'ENTITY')
# ('mental status', 149, 162, 'ENTITY')
# ('hypotension', 163, 174, 'ENTITY')
# ('surgical invasive procedure history', 181, 216, 'ENTITY')
# ('illness age', 225, 236, 'ENTITY')
# ('refractory', 242, 252, 'ENTITY')
# ('hodgkins lymphoma', 272, 289, 'ENTITY')
# ('ems', 298, 301, 'ENTITY')
# ('hypotensive', 339, 350, 'ENTITY')
# ('incontinant', 391, 402, 'ENTITY')
# ('stool', 403, 408, 'ENTITY')
# ('treated', 409, 416, 'ENTITY')
# ('vanco', 424, 429, 'ENTITY')
# ('ativan', 485, 491, 'ENTITY')
# ('morphine', 500, 508, 'ENTITY')
# ('agitation', 509, 518, 'ENTITY')
# ('admitted hospital unit', 522, 544, 'ENTITY')
# ('course', 559, 565, 'ENTITY')
# ('ceftazadime', 566, 577, 'ENTITY')
# ('vancomycin', 578, 588, 'ENTITY')
# ('urosepsis', 589, 598, 'ENTITY')
# ('course', 599, 605, 'ENTITY')
# ('metronidazole', 606, 619, 'ENTITY')
# ('empiric treatment', 630, 647, 'ENTITY')
# ('loose stools', 659, 671, 'ENTITY')
# ('elevated', 680, 688, 'ENTITY')
# ('wbc count diff assays', 689, 710, 'ENTITY')
# ('negative', 711, 719, 'ENTITY')
# ('stabilized', 723, 733, 'ENTITY')
# ('transferred floor', 734, 751, 'ENTITY')
# ('time transfer', 757, 770, 'ENTITY')
# ('active issues', 771, 784, 'ENTITY')
# ('nutritional status thrombocytopenia', 790, 825, 'ENTITY')
# ('anemia', 826, 832, 'ENTITY')
# ('floor', 833, 838, 'ENTITY')
# ('episode', 854, 861, 'ENTITY')
# ('afib rvr', 866, 874, 'ENTITY')
# ('hypotension', 875, 886, 'ENTITY')
# ('respiratory distress', 894, 914, 'ENTITY')
# ('fluid resuscitation concern syndrome', 924, 960, 'ENTITY')
# ('pauses', 961, 967, 'ENTITY')
# ('digoxin', 1001, 1008, 'ENTITY')
# ('readmitted', 1024, 1034, 'ENTITY')
# ('micu', 1035, 1039, 'ENTITY')
# ('micu', 1040, 1044, 'ENTITY')
# ('vancomycin', 1053, 1063, 'ENTITY')
# ('sites', 1066, 1071, 'ENTITY')
# ('infection', 1081, 1090, 'ENTITY')
# ('erosions', 1091, 1099, 'ENTITY')
# ('breasts right', 1100, 1113, 'ENTITY')
# ('micu', 1168, 1172, 'ENTITY')
# ('course', 1173, 1179, 'ENTITY')
# ('hypotension', 1189, 1200, 'ENTITY')
# ('low', 1231, 1234, 'ENTITY')
# ('hypovolemia', 1253, 1264, 'ENTITY')
# ('baseline', 1269, 1277, 'ENTITY')
# ('nitrogenous urine output', 1278, 1302, 'ENTITY')
# ('amiodarone', 1333, 1343, 'ENTITY')
# ('daily', 1354, 1359, 'ENTITY')
# ('days', 1366, 1370, 'ENTITY')
# ('downward', 1381, 1389, 'ENTITY')
# ('medical history', 1395, 1410, 'ENTITY')
# ('nodular sclerosing', 1411, 1429, 'ENTITY')
# ('hodgkins lymphoma', 1430, 1447, 'ENTITY')
# ('lymphadenopathy', 1457, 1472, 'ENTITY')
# ('treated', 1473, 1480, 'ENTITY')
# ('local radiotherapy', 1481, 1499, 'ENTITY')
# ('progression', 1528, 1539, 'ENTITY')
# ('treated', 1540, 1547, 'ENTITY')
# ('cytoxan', 1548, 1555, 'ENTITY')
# ('prednisone', 1563, 1573, 'ENTITY')
# ('treated', 1600, 1607, 'ENTITY')
# ('radiation therapy', 1608, 1625, 'ENTITY')
# ('hypoxemia somnolence generalized edema anasarca', 1633, 1680, 'ENTITY')
# ('discharged constant', 1720, 1739, 'ENTITY')
# ('trial', 1752, 1757, 'ENTITY')
# ('low blood counts', 1772, 1788, 'ENTITY')
# ('chlorambucil', 1806, 1818, 'ENTITY')
# ('daily', 1824, 1829, 'ENTITY')
# ('days', 1830, 1834, 'ENTITY')
# ('procarbazine', 1840, 1852, 'ENTITY')
# ('daily', 1859, 1864, 'ENTITY')
# ('days', 1865, 1869, 'ENTITY')
# ('velban', 1875, 1881, 'ENTITY')
# ('day', 1911, 1914, 'ENTITY')
# ('chemotherapy', 1917, 1929, 'ENTITY')
# ('poor response', 1949, 1962, 'ENTITY')
# ('sided chest', 1965, 1976, 'ENTITY')
# ('lytic lesions', 1982, 1995, 'ENTITY')
# ('radiation therapy', 2024, 2041, 'ENTITY')
# ('right rib interval', 2052, 2070, 'ENTITY')
# ('decrease', 2071, 2079, 'ENTITY')
# ('vertebral lesions', 2080, 2097, 'ENTITY')
# ('lower extremity cellulitis', 2098, 2124, 'ENTITY')
# ('gerd arthritis', 2125, 2139, 'ENTITY')
# ('chronic ble edema hypothyroidism', 2140, 2172, 'ENTITY')
# ('constipation', 2186, 2198, 'ENTITY')
# ('social history', 2199, 2213, 'ENTITY')
# ('home health care', 2220, 2236, 'ENTITY')
# ('son ni', 2242, 2248, 'ENTITY')
# ('care children', 2258, 2271, 'ENTITY')
# ('alcohol illicit drug', 2280, 2300, 'ENTITY')
# ('family history', 2305, 2319, 'ENTITY')
# ('noncontributory', 2320, 2335, 'ENTITY')
# ('physical exam', 2336, 2349, 'ENTITY')
# ('physical exam', 2358, 2371, 'ENTITY')
# ('elderly', 2380, 2387, 'ENTITY')
# ('female', 2388, 2394, 'ENTITY')
# ('minimally reponsive verbal stimuli', 2410, 2444, 'ENTITY')
# ('tactile', 2456, 2463, 'ENTITY')
# ('stimulation', 2464, 2475, 'ENTITY')
# ('moist', 2537, 2542, 'ENTITY')
# ('mucous membranes', 2543, 2559, 'ENTITY')
# ('carotid pulses', 2567, 2581, 'ENTITY')
# ('lungs', 2602, 2607, 'ENTITY')
# ('abd soft', 2670, 2678, 'ENTITY')
# ('non tender percussion ext pitting edema feet bilaterally nonpalpable', 2712, 2780, 'ENTITY')
# ('capillary refill bilaterally neuro', 2809, 2843, 'ENTITY')
# ('pupils', 2861, 2867, 'ENTITY')
# ('bilaterally', 2875, 2886, 'ENTITY')
# ('painful', 2897, 2904, 'ENTITY')
# ('increased', 2927, 2936, 'ENTITY')
# ('tone mute', 2937, 2946, 'ENTITY')
# ('bilaterally toes', 2956, 2972, 'ENTITY')
# ('physical exam', 2990, 3003, 'ENTITY')
# ('time transfer', 3004, 3017, 'ENTITY')
# ('elderly', 3065, 3072, 'ENTITY')
# ('female', 3073, 3079, 'ENTITY')
# ('minimally reponsive verbal stimuli', 3095, 3129, 'ENTITY')
# ('tactile', 3140, 3147, 'ENTITY')
# ('dry mucous membranes', 3183, 3203, 'ENTITY')
# ('carotid pulses', 3211, 3225, 'ENTITY')
# ('jvp', 3230, 3233, 'ENTITY')
# ('breath sounds bases', 3261, 3280, 'ENTITY')
# ('bilaterally', 3281, 3292, 'ENTITY')
# ('abd soft distended', 3328, 3346, 'ENTITY')
# ('active bowel sounds', 3347, 3366, 'ENTITY')
# ('non tender percussion ext pitting edema extremities', 3367, 3418, 'ENTITY')
# ('bilaterally nonpalpable', 3419, 3442, 'ENTITY')
# ('capillary refill bilaterally neuro', 3471, 3505, 'ENTITY')
# ('pupils 3 4', 3523, 3533, 'ENTITY')
# ('bilaterally', 3537, 3548, 'ENTITY')
# ('painful', 3559, 3566, 'ENTITY')
# ('stimuli', 3567, 3574, 'ENTITY')
# ('reflexes bilaterally physical exam transfer', 3586, 3629, 'ENTITY')
# ('micu', 3630, 3634, 'ENTITY')
# ('temp bp', 3638, 3645, 'ENTITY')
# ('lnc', 3664, 3667, 'ENTITY')
# ('gen pleasant comfortable nad', 3668, 3696, 'ENTITY')
# ('somnolent', 3706, 3715, 'ENTITY')
# ('heent', 3736, 3741, 'ENTITY')
# ('eomi', 3748, 3752, 'ENTITY')
# ('anicteric tachy', 3753, 3768, 'ENTITY')
# ('lesions', 3775, 3782, 'ENTITY')
# ('neck supraclavicular cervical lymphadenopathy jvd resp occ crackle bases', 3783, 3855, 'ENTITY')
# ('patient', 3873, 3880, 'ENTITY')
# ('cooperative exam', 3881, 3897, 'ENTITY')
# ('involvement', 3963, 3974, 'ENTITY')
# ('upper limbs', 3975, 3986, 'ENTITY')
# ('skin rashes', 3987, 3998, 'ENTITY')
# ('jaundice neuro', 3999, 4013, 'ENTITY')
# ('somnolent', 4023, 4032, 'ENTITY')
# ('neuro', 4070, 4075, 'ENTITY')
# ('somnolence pertinent results', 4087, 4115, 'ENTITY')
# ('consolidation', 4164, 4177, 'ENTITY')
# ('routine', 4178, 4185, 'ENTITY')
# ('pa lateral', 4186, 4196, 'ENTITY')
# ('films', 4197, 4202, 'ENTITY')
# ('evaluation', 4215, 4225, 'ENTITY')
# ('echo left atrium', 4240, 4256, 'ENTITY')
# ('atrial septal defect', 4269, 4289, 'ENTITY')
# ('color', 4295, 4300, 'ENTITY')
# ('doppler left ventricular wall', 4301, 4330, 'ENTITY')
# ('left ventricular cavity', 4350, 4373, 'ENTITY')
# ('left ventricular systolic function', 4394, 4428, 'ENTITY')
# ('free wall motion normal', 4467, 4490, 'ENTITY')
# ('valve leaflets', 4498, 4512, 'ENTITY')
# ('trace aortic regurgitation', 4563, 4589, 'ENTITY')
# ('mitral valve leaflets', 4595, 4616, 'ENTITY')
# ('physiologic', 4634, 4645, 'ENTITY')
# ('mitral regurgitation', 4646, 4666, 'ENTITY')
# ('pulmonary artery', 4695, 4711, 'ENTITY')
# ('pericardial effusion', 4734, 4754, 'ENTITY')
# ('endocarditis', 4770, 4782, 'ENTITY')
# ('prophylaxis', 4783, 4794, 'ENTITY')
# ('recommendations', 4795, 4810, 'ENTITY')
# ('echo findings', 4811, 4824, 'ENTITY')
# ('prophylaxis', 4834, 4845, 'ENTITY')
# ('clinical decisions', 4858, 4876, 'ENTITY')
# ('prophylaxis', 4882, 4893, 'ENTITY')
# ('clinical', 4900, 4908, 'ENTITY')
# ('echocardiographic', 4909, 4926, 'ENTITY')
# ('data', 4927, 4931, 'ENTITY')
# ('study images', 4954, 4966, 'ENTITY')
# ('review', 4979, 4985, 'ENTITY')
# ('hospital course', 5019, 5034, 'ENTITY')
# ('age', 5035, 5038, 'ENTITY')
# ('nodular sclerosing hodgkin lymphoma', 5044, 5079, 'ENTITY')
# ('urosepsis', 5099, 5108, 'ENTITY')
# ('icu hypotension', 5121, 5136, 'ENTITY')
# ('goals care', 5146, 5156, 'ENTITY')
# ('patient', 5157, 5164, 'ENTITY')
# ('long hospital course', 5165, 5185, 'ENTITY')
# ('family meetings reagarding', 5186, 5212, 'ENTITY')
# ('goals care', 5213, 5223, 'ENTITY')
# ('patient', 5234, 5241, 'ENTITY')
# ('icu transfers', 5264, 5277, 'ENTITY')
# ('pressors', 5278, 5286, 'ENTITY')
# ('comfort', 5305, 5312, 'ENTITY')
# ('patient', 5313, 5320, 'ENTITY')
# ('patient', 5321, 5328, 'ENTITY')
# ('levophed hypotension', 5363, 5383, 'ENTITY')
# ('decision medically futile', 5395, 5420, 'ENTITY')
# ('escalate care care', 5421, 5439, 'ENTITY')
# ('family', 5467, 5473, 'ENTITY')
# ('autopsy', 5483, 5490, 'ENTITY')
# ('afib', 5491, 5495, 'ENTITY')
# ('transient', 5515, 5524, 'ENTITY')
# ('controlled', 5543, 5553, 'ENTITY')
# ('diltiazem', 5554, 5563, 'ENTITY')
# ('metoprolol', 5564, 5574, 'ENTITY')
# ('spontaneous', 5575, 5586, 'ENTITY')
# ('conversion', 5587, 5597, 'ENTITY')
# ('pauses', 5625, 5631, 'ENTITY')
# ('bradycardia', 5632, 5643, 'ENTITY')
# ('junctional escape', 5654, 5671, 'ENTITY')
# ('digoxin', 5672, 5679, 'ENTITY')
# ('patient', 5703, 5710, 'ENTITY')
# ('micu', 5711, 5715, 'ENTITY')
# ('amiodarone', 5727, 5737, 'ENTITY')
# ('gtt', 5738, 5741, 'ENTITY')
# ('amiodarone', 5752, 5762, 'ENTITY')
# ('patient readmitted', 5766, 5784, 'ENTITY')
# ('increased', 5806, 5815, 'ENTITY')
# ('pauses', 5816, 5822, 'ENTITY')
# ('amiodarone', 5834, 5844, 'ENTITY')
# ('patient', 5853, 5860, 'ENTITY')
# ('anemia', 5861, 5867, 'ENTITY')
# ('thrombocytopenic admission', 5868, 5894, 'ENTITY')
# ('secondary marrow infiltration lymphoma', 5903, 5941, 'ENTITY')
# ('transfused', 5942, 5952, 'ENTITY')
# ('plt 1 unit', 5967, 5977, 'ENTITY')
# ('transfusion', 5988, 5999, 'ENTITY')
# ('threshold', 6000, 6009, 'ENTITY')
# ('trend', 6022, 6027, 'ENTITY')
# ('platelets', 6028, 6037, 'ENTITY')
# ('transfuse bleeding', 6038, 6056, 'ENTITY')
# ('platelet count', 6057, 6071, 'ENTITY')
# ('platelets', 6093, 6102, 'ENTITY')
# ('patient', 6118, 6125, 'ENTITY')
# ('prbc transfusions', 6136, 6153, 'ENTITY')
# ('hypotension', 6183, 6194, 'ENTITY')
# ('hypotensive episodes', 6218, 6238, 'ENTITY')
# ('furosemide', 6239, 6249, 'ENTITY')
# ('responsive', 6250, 6260, 'ENTITY')
# ('fluid', 6261, 6266, 'ENTITY')
# ('blosues', 6267, 6274, 'ENTITY')
# ('echo', 6282, 6286, 'ENTITY')
# ('impaired', 6300, 6308, 'ENTITY')
# ('lv relaxation', 6309, 6322, 'ENTITY')
# ('elevated', 6329, 6337, 'ENTITY')
# ('phenylephrine', 6401, 6414, 'ENTITY')
# ('gtt', 6415, 6418, 'ENTITY')
# ('weaned hypotension', 6419, 6437, 'ENTITY')
# ('admission', 6444, 6453, 'ENTITY')
# ('secondary', 6462, 6471, 'ENTITY')
# ('systemic vasodilation', 6472, 6493, 'ENTITY')
# ('levophed decision escalate care infection', 6502, 6543, 'ENTITY')
# ('elevated', 6548, 6556, 'ENTITY')
# ('infectious', 6575, 6585, 'ENTITY')
# ('sources', 6586, 6593, 'ENTITY')
# ('hypotension', 6605, 6616, 'ENTITY')
# ('skin erosions', 6620, 6633, 'ENTITY')
# ('breasts', 6634, 6641, 'ENTITY')
# ('breath sounds pna vanc', 6649, 6671, 'ENTITY')
# ('piptaz', 6672, 6678, 'ENTITY')
# ('cultures', 6692, 6700, 'ENTITY')
# ('blood urine', 6701, 6712, 'ENTITY')
# ('sputum', 6721, 6727, 'ENTITY')
# ('point cdiff', 6739, 6750, 'ENTITY')
# ('flagyl 1', 6777, 6785, 'ENTITY')
# ('skin swab hypernatremia', 6793, 6816, 'ENTITY')
# ('hypernatremic admission', 6836, 6859, 'ENTITY')
# ('free water', 6871, 6881, 'ENTITY')
# ('intake', 6921, 6927, 'ENTITY')
# ('free water', 6933, 6943, 'ENTITY')
# ('mental status', 6959, 6972, 'ENTITY')
# ('increased', 6973, 6982, 'ENTITY')
# ('lethargy', 6983, 6991, 'ENTITY')
# ('baseline admission', 7001, 7019, 'ENTITY')
# ('metabolic encephalopathy', 7032, 7056, 'ENTITY')
# ('respiratory distress', 7211, 7231, 'ENTITY')
# ('admission', 7238, 7247, 'ENTITY')
# ('patient', 7248, 7255, 'ENTITY')
# ('labored breathing', 7266, 7283, 'ENTITY')
# ('ns hypotension flash pulmonary edema diuresis furosemide', 7298, 7354, 'ENTITY')
# ('gtt lead hypotension', 7355, 7375, 'ENTITY')
# ('resuscitation lead', 7384, 7402, 'ENTITY')
# ('respiratory distress', 7412, 7432, 'ENTITY')
# ('floor', 7443, 7448, 'ENTITY')
# ('event', 7470, 7475, 'ENTITY')
# ('flow mask icu', 7490, 7503, 'ENTITY')
# ('weaned', 7504, 7510, 'ENTITY')
# ('increasing', 7521, 7531, 'ENTITY')
# ('requirements', 7532, 7544, 'ENTITY')
# ('acute renal failure', 7545, 7564, 'ENTITY')
# ('cr admission', 7574, 7586, 'ENTITY')
# ('baseline', 7596, 7604, 'ENTITY')
# ('baseline', 7614, 7622, 'ENTITY')
# ('dehydration hypotension sepsis', 7630, 7660, 'ENTITY')
# ('hospital course', 7667, 7682, 'ENTITY')
# ('patient', 7683, 7690, 'ENTITY')
# ('hypotensive creatinine', 7691, 7713, 'ENTITY')
# ('secondary atn hypothyroidism', 7733, 7761, 'ENTITY')
# ('treated', 7772, 7779, 'ENTITY')
# ('levothyroxine', 7780, 7793, 'ENTITY')
# ('elevated', 7830, 7838, 'ENTITY')
# ('home dose', 7847, 7856, 'ENTITY')
# ('anasarca', 7857, 7865, 'ENTITY')
# ('edema', 7877, 7882, 'ENTITY')
# ('bilateral', 7889, 7898, 'ENTITY')
# ('pleural effusions', 7899, 7916, 'ENTITY')
# ('malnutrition', 7924, 7936, 'ENTITY')
# ('low albumin admission', 7943, 7964, 'ENTITY')
# ('intake', 7973, 7979, 'ENTITY')
# ('diuresis', 7980, 7988, 'ENTITY')
# ('difficult', 7989, 7998, 'ENTITY')
# ('hypotension', 7999, 8010, 'ENTITY')
# ('urosepsis', 8037, 8046, 'ENTITY')
# ('admitted', 8047, 8055, 'ENTITY')
# ('hypotension urosepsis', 8056, 8077, 'ENTITY')
# ('pressor', 8088, 8095, 'ENTITY')
# ('urine cultures', 8104, 8118, 'ENTITY')
# ('positive', 8123, 8131, 'ENTITY')
# ('treated', 8145, 8152, 'ENTITY')
# ('vancomycin', 8153, 8163, 'ENTITY')
# ('ceftazidime', 8164, 8175, 'ENTITY')
# ('days', 8176, 8180, 'ENTITY')
# ('yeast', 8207, 8212, 'ENTITY')
# ('treated', 8213, 8220, 'ENTITY')
# ('right acetabulum', 8286, 8302, 'ENTITY')
# ('medial', 8352, 8358, 'ENTITY')
# ('osseous', 8416, 8423, 'ENTITY')
# ('right sacral ala iliac bone', 8496, 8523, 'ENTITY')
# ('patient pain', 8524, 8536, 'ENTITY')
# ('controlled', 8537, 8547, 'ENTITY')
# ('fentanyl lidocaine', 8548, 8566, 'ENTITY')
# ('bilateral', 8575, 8584, 'ENTITY')
# ('pleural effusion', 8585, 8601, 'ENTITY')
# ('agressive', 8621, 8630, 'ENTITY')
# ('sepsis hypoalbuminemia', 8649, 8671, 'ENTITY')
# ('effect significant', 8682, 8700, 'ENTITY')
# ('micu', 8709, 8713, 'ENTITY')
# ('development', 8714, 8725, 'ENTITY')
# ('hypotension', 8726, 8737, 'ENTITY')
# ('furosemide', 8747, 8757, 'ENTITY')
# ('improved', 8775, 8783, 'ENTITY')
# ('unchanged', 8798, 8807, 'ENTITY')
# ('nodular sclerosing hodgkin lymphoma', 8817, 8852, 'ENTITY')
# ('oncology interventions', 8858, 8880, 'ENTITY')
# ('bone marrow', 8893, 8904, 'ENTITY')
# ('anemia thrombocytopenia', 8926, 8949, 'ENTITY')
# ('hemolysis', 8978, 8987, 'ENTITY')
# ('treatment', 8988, 8997, 'ENTITY')
# ('oncology coagulopathy', 8998, 9019, 'ENTITY')
# ('mild', 9020, 9024, 'ENTITY')
# ('nutritional deficiency', 9032, 9054, 'ENTITY')
# ('po', 9065, 9067, 'ENTITY')
# ('intake', 9068, 9074, 'ENTITY')
# ('trend lfts', 9075, 9085, 'ENTITY')
# ('coags medications', 9086, 9103, 'ENTITY')
# ('admission', 9104, 9113, 'ENTITY')
# ('medications', 9114, 9125, 'ENTITY')
# ('admission', 9126, 9135, 'ENTITY')
# ('levothyroxine', 9138, 9151, 'ENTITY')
# ('daily', 9159, 9164, 'ENTITY')
# ('docusate sodium', 9167, 9182, 'ENTITY')
# ('omeprazole', 9192, 9202, 'ENTITY')
# ('ferrous sulfate', 9232, 9247, 'ENTITY')
# ('daily', 9255, 9260, 'ENTITY')
# ('qid', 9275, 9278, 'ENTITY')
# ('ultram', 9285, 9291, 'ENTITY')
# ('lasix', 9310, 9315, 'ENTITY')
# ('senna', 9330, 9335, 'ENTITY')
# ('aspirin', 9346, 9353, 'ENTITY')
# ('potassium chloride', 9369, 9387, 'ENTITY')
# ('multivitamin medications', 9391, 9415, 'ENTITY')
# ('acetaminophen', 9427, 9440, 'ENTITY')
# ('affected', 9498, 9506, 'ENTITY')
# ('folic acid 1', 9514, 9526, 'ENTITY')
# ('cap po daily 5', 9557, 9571, 'ENTITY')
# ('ipratropium bromide', 9572, 9591, 'ENTITY')
# ('neb 1 neb', 9592, 9601, 'ENTITY')
# ('bisacodyl', 9607, 9616, 'ENTITY')
# ('daily', 9623, 9628, 'ENTITY')
# ('tab', 9643, 9646, 'ENTITY')
# ('bid constipation', 9650, 9666, 'ENTITY')
# ('docusate sodium', 9669, 9684, 'ENTITY')
# ('bid', 9695, 9698, 'ENTITY')
# ('albuterol', 9701, 9710, 'ENTITY')
# ('neb soln', 9711, 9719, 'ENTITY')
# ('neb', 9722, 9725, 'ENTITY')
# ('metronidazole', 9736, 9749, 'ENTITY')
# ('flagyl', 9750, 9756, 'ENTITY')
# ('fentanyl', 9770, 9778, 'ENTITY')
# ('lidocaine', 9794, 9803, 'ENTITY')
# ('patch', 9806, 9811, 'ENTITY')
# ('ptch', 9814, 9818, 'ENTITY')
# ('right hip day', 9831, 9844, 'ENTITY')
# ('sarna lotion 1 appl', 9864, 9883, 'ENTITY')
# ('levothyroxine sodium', 9898, 9918, 'ENTITY')
# ('pantoprazole', 9935, 9947, 'ENTITY')
# ('iv discharge', 9954, 9966, 'ENTITY')
# ('medications', 9967, 9978, 'ENTITY')
# ('patient', 9979, 9986, 'ENTITY')
# ('discharge disposition', 10004, 10025, 'ENTITY')
# ('care discharge', 10035, 10049, 'ENTITY')
# ('urosepsis', 10060, 10069, 'ENTITY')
# ('aspiration pneumonitis', 10070, 10092, 'ENTITY')
# ('atrial fibrillation rvr lymphoma', 10093, 10125, 'ENTITY')
# ('condition', 10136, 10145, 'ENTITY')
# ('patient', 10146, 10153, 'ENTITY')
# ('discharge instructions', 10171, 10193, 'ENTITY')
# ('patient', 10194, 10201, 'ENTITY')
# ('followup', 10219, 10227, 'ENTITY')
# ('instructions', 10228, 10240, 'ENTITY')
# ('patient', 10241, 10248, 'ENTITY')
# ('initials', 10266, 10274, 'ENTITY')

# %%
# Visualize entities in the first discharge summary PROCESSED_TEXT
doc = scispacy_nlp(ecoli_df['SCISPACY_PROCESSED_TEXT'].iloc[0])
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     admission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  date 2194 1 7
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     discharge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  date 2194 2 2
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     service medicine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  allergies
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     patient
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  recorded having known
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     allergies drugs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  290
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chief complaint
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  altered
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mental status
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypotension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  major
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     surgical invasive procedure history
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  present
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     illness age
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  90 f
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     refractory
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  nodular sclerosing
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hodgkins lymphoma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  brought
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ems
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  admitted home health care aide noted
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypotensive
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  confused ed t rectal hr 101 bp rr 20 98
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     incontinant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     stool
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     treated
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  4 l ns
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vanco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  1 g iv ceftazadime 1 g iv flagyl 500 mg iv received mg
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ativan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  2 mg iv
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     morphine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     agitation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  pt
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     admitted hospital unit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  153 completed
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     course
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ceftazadime
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vancomycin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left:

# %% [markdown]
# # Corpus & Word Vectors

# %%
# Build a corpus of processed text
corpus = []

# Iterate through PROCESSED_TEXT on only the first 5 rows
for row in range(0, 5):
    str_tokens = []
    text = ecoli_df['SCISPACY_PROCESSED_TEXT'].iloc[row]
    print(f"Processing row {row}: {text}")
    tokens = scispacy_nlp(text).ents
    if not tokens:
        print(f"No entities found in row {row}")
    for i in range(0, len(tokens)):
        str_tokens.append(tokens[i].text)
    corpus.append(list(str_tokens))

print(corpus)
# Out:
# Processing row 0: admission date 2194 1 7 discharge date 2194 2 2 service medicine allergies patient recorded having known allergies drugs 290 chief complaint altered mental status hypotension major surgical invasive procedure history present illness age 90 f refractory nodular sclerosing hodgkins lymphoma brought ems admitted home health care aide noted hypotensive confused ed t rectal hr 101 bp rr 20 98 incontinant stool treated 4 l ns vanco 1 g iv ceftazadime 1 g iv flagyl 500 mg iv received mg ativan 2 mg iv morphine agitation pt admitted hospital unit 153 completed course ceftazadime vancomycin urosepsis course metronidazole completed empiric treatment diff given loose stools setting elevated wbc count diff assays negative pt stabilized transferred floor care time transfer active issues poor nutritional status thrombocytopenia anemia floor pt experienced episode new afib rvr hypotension sbp 90 respiratory distress received fluid resuscitation concern syndrome pauses 4 sec telemetry ep curbside felt digoxin recommended pt readmitted micu micu started vancomycin 1 sites possible infection erosions breasts right hip question pna 2 rising wbc reaching high nearly 17 micu course marked 1 hypotension responded gentle ns boluses 2 low uop believed 2 22 hypov
nutritional status thrombocytopenia', 'anemia', 'floor', 'episode', 'afib rvr', 'hypotension', 'respiratory distress', 'fluid resuscitation concern syndrome', 'pauses', 'digoxin', 'readmitted', 'micu', 'micu', 'vancomycin', 'sites', 'infection', 'erosions', 'breasts right', 'micu', 'course', 'hypotension', 'low', 'hypovolemia', 'baseline', 'nitrogenous urine output', 'amiodarone', 'daily', 'days', 'downward', 'medical history', 'nodular sclerosing', 'hodgkins lymphoma', 'lymphadenopathy', 'treated', 'local radiotherapy', 'progression', 'treated', 'cytoxan', 'prednisone', 'treated', 'radiation therapy', 'hypoxemia somnolence generalized edema anasarca', 'discharged constant', 'trial', 'low blood counts', 'chlorambucil', 'daily', 'days', 'procarbazine', 'daily', 'days', 'velban', 'day', 'chemotherapy', 'poor response', 'sided chest', 'lytic lesions', 'radiation therapy', 'right rib interval', 'decrease', 'vertebral lesions', 'lower extremity cellulitis', 'gerd arthritis', 'chronic ble edema hypothyroidism', 'constipation', 'social history', 'home health care', 'son ni', 'care children', 'alcohol illicit drug', 'family history', 'noncontributory', 'physical exam', 'physical exam', 'elderly', 'female', 'minimally reponsive verbal stimuli', 'tactile', 'stimulation', 'moist', 'mucous membranes', 'carotid pulses', 'lungs', 'abd soft', 'non tender percussion ext pitting edema feet bilaterally nonpalpable', 'capillary refill bilaterally neuro', 'pupils', 'bilaterally', 'painful', 'increased', 'tone mute', 'bilaterally toes', 'physical exam', 'time transfer', 'elderly', 'female', 'minimally reponsive verbal stimuli', 'tactile', 'dry mucous membranes', 'carotid pulses', 'jvp', 'breath sounds bases', 'bilaterally', 'abd soft distended', 'active bowel sounds', 'non tender percussion ext pitting edema extremities', 'bilaterally nonpalpable', 'capillary refill bilaterally neuro', 'pupils 3 4', 'bilaterally', 'painful', 'stimuli', 'reflexes bilaterally physical exam transfer', 'micu', 'temp bp', 'lnc', 'gen pleasant comfortable nad', 'somnolent', 'heent', 'eomi', 'anicteric tachy', 'lesions', 'neck supraclavicular cervical lymphadenopathy jvd resp occ crackle bases', 'patient', 'cooperative exam', 'involvement', 'upper limbs', 'skin rashes', 'jaundice neuro', 'somnolent', 'neuro', 'somnolence pertinent results', 'consolidation', 'routine', 'pa lateral', 'films', 'evaluation', 'echo left atrium', 'atrial septal defect', 'color', 'doppler left ventricular wall', 'left ventricular cavity', 'left ventricular systolic function', 'free wall motion normal', 'valve leaflets', 'trace aortic regurgitation', 'mitral valve leaflets', 'physiologic', 'mitral regurgitation', 'pulmonary artery', 'pericardial effusion', 'endocarditis', 'prophylaxis', 'recommendations', 'echo findings', 'prophylaxis', 'clinical decisions', 'prophylaxis', 'clinical', 'echocardiographic', 'data', 'study images', 'review', 'hospital course', 'age', 'nodular sclerosing hodgkin lymphoma', 'urosepsis', 'icu hypotension', 'goals care', 'patient', 'long hospital course', 'family meetings reagarding', 'goals care', 'patient', 'icu transfers', 'pressors', 'comfort', 'patient', 'patient', 'levophed hypotension', 'decision medically futile', 'escalate care care', 'family', 'autopsy', 'afib', 'transient', 'controlled', 'diltiazem', 'metoprolol', 'spontaneous', 'conversion', 'pauses', 'bradycardia', 'junctional escape', ' ...

# %% [markdown]
# # Word Vectors

# %%
from gensim.models import Word2Vec
word2vec_model = Word2Vec(corpus, min_count=1)
# Find the word vector for 'antibiotics'
word2vec_model.wv['antibiotics']
# Out:
# array([ 0.00127839,  0.00132863, -0.00432331, -0.00381365,  0.00630039,
#         0.00587752, -0.00165661,  0.00383083, -0.00406939, -0.00390675,
#         0.0061278 , -0.00633481,  0.00861772,  0.00040693,  0.00759922,
#         0.00331962,  0.00091629,  0.00103476,  0.00483985, -0.00023541,
#         0.0010482 , -0.00449519, -0.00946564, -0.00085228,  0.00969883,
#        -0.0017203 , -0.00411841, -0.0055458 , -0.00393655, -0.00337988,
#        -0.00130955,  0.00345893, -0.00108947,  0.00660341, -0.00199067,
#        -0.00040092, -0.00051604,  0.00150951, -0.00960396,  0.00096202,
#         0.00748328, -0.0067242 ,  0.0078347 ,  0.00856227, -0.00885135,
#        -0.00232461, -0.01002464, -0.00561671,  0.00651266,  0.00814657,
#        -0.00342166,  0.00508335, -0.0049611 ,  0.00051807, -0.00736328,
#        -0.00173554,  0.00910663, -0.00050654, -0.00411689, -0.00306152,
#         0.00971283,  0.00723693,  0.00765387,  0.00404767,  0.00866525,
#         0.00653758,  0.00890762,  0.00347636, -0.00887182,  0.00340475,
#         0.00478211,  0.00422526,  0.00358734,  0.00483433,  0.00084302,
#        -0.00906825,  0.00973294,  0.00988762,  0.00014675, -0.00827446,
#        -0.00983679,  0.00079985, -0.00306615, -0.00483288,  0.00544199,
#        -0.009021  ,  0.00229997, -0.00025632,  0.00578564,  0.00221817,
#        -0.00795531, -0.00219638,  0.00579097,  0.00637872, -0.00499631,
#        -0.00245395, -0.00930085,  0.00671605,  0.00994765,  0.00858904],
#       dtype=float32)

# %%
word2vec_model.wv.similar_by_word('antibiotics')
# Out:
# [('discharge', 0.2776538133621216),
#  ('reflexes bilaterally physical exam transfer', 0.27713921666145325),
#  ('lungs ctab', 0.2666809558868408),
#  ('dose', 0.26522624492645264),
#  ('surgeries', 0.2628735899925232),
#  ('metronidazole', 0.25460758805274963),
#  ('trend lfts', 0.24225164949893951),
#  ('autopsy', 0.24105584621429443),
#  ('gram positive cocci bacteremia', 0.2357354760169983),
#  ('daily', 0.23296909034252167)]

# %%
word2vec_model.wv.similarity('antibiotics', 'bacteria')
# Out:
# -0.011203538

# %% [markdown]
# # t-SNE Visualization

# %%
from sklearn.cluster import KMeans
import random

def tsne_plot(model, words, preTrained=False, max_words=100, n_clusters=5):
    "Creates and TSNE model and plots it with K-Means clustering"
    labels = []
    tokens = []

    # Sample a subset of words if there are too many
    if len(words) > max_words:
        words = random.sample(words, max_words)

    for word in words:
        if preTrained:
            tokens.append(model[word])
        else:
            tokens.append(model.wv[word])
        labels.append(word)

    tokens = np.array(tokens)
    tsne_model = TSNE(perplexity=5, early_exaggeration=50, n_components=2, init='pca', n_iter=1000, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    # Perform K-Means clustering
    kmeans = KMeans(n_clusters=n_clusters, random_state=23)
    kmeans.fit(new_values)
    cluster_labels = kmeans.labels_

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])

    plt.figure(figsize=(16, 16))
    colors = plt.cm.rainbow(np.linspace(0, 1, n_clusters))
    for i in range(len(x)):
        plt.scatter(x[i], y[i], color=colors[cluster_labels[i]])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()

# %%
# Visualize word embeddings using TSNE, indexed by the word2vec model's vocabulary
vocabs = word2vec_model.wv.index_to_key
new_v = list(vocabs)
tsne_plot(word2vec_model, new_v, preTrained=False, max_words=150)
# Out:
# /Users/jefdewitt/miniconda3/envs/new_env/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %% [markdown]
# # Topic Modeling w/ LDA

# %%
import pyLDAvis
import pyLDAvis.gensim_models
from gensim import corpora
from gensim.models import LdaModel
from sklearn.feature_extraction.text import CountVectorizer
import re

def preprocess_texts(texts):
    # Remove numbers from the texts
    texts = [re.sub(r'\d+', '', text) for text in texts]
    
    # Tokenize and clean the texts
    vectorizer = CountVectorizer(stop_words='english')
    text_matrix = vectorizer.fit_transform(texts)
    tokens = [text.split() for text in texts]
    return tokens, vectorizer

def get_top_words(lda_model, num_words=5):
    top_words = {}
    for idx, topic in lda_model.print_topics(-1):
        words = topic.split(' + ')
        top_words[idx] = ', '.join([word.split('*')[1].strip('"') for word in words[:num_words]])
    return top_words

def lda_topic_modeling(texts, n_topics=5):
    tokens, vectorizer = preprocess_texts(texts)
    
    # Create a dictionary and corpus for LDA
    dictionary = corpora.Dictionary(tokens)
    corpus = [dictionary.doc2bow(token) for token in tokens]

    # Fit the LDA model
    lda_model = LdaModel(corpus, num_topics=n_topics, id2word=dictionary, random_state=23)

    # Print the top words for each topic
    top_words = get_top_words(lda_model)
    for idx, words in top_words.items():
        print(f"Topic {idx}: {words}")
        print("\n")

    # Visualize the topics
    pyLDAvis.enable_notebook()
    panel = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)
    return panel

texts = ecoli_df['SCISPACY_PROCESSED_TEXT'].tolist()
panel = lda_topic_modeling(texts, n_topics=5)

# Save the visualization to an HTML file
output_filepath = '/Users/jefdewitt/Documents/education/UT-Austin/courses/ai-in-healthcare/module-6/lda_visualization.html'
pyLDAvis.save_html(panel, output_filepath)
print(f"LDA visualization saved to {output_filepath}")
# Out:
# Topic 0: mg, po, tablet, patient, sig
#
#
# Topic 1: blood, mg, tablet, po, patient
#
#
# Topic 2: blood, patient, mg, po, discharge
#
#
# Topic 3: mg, tablet, blood, patient, sig
#
#
# Topic 4: mg, po, patient, daily, blood
#
#
# LDA visualization saved to /Users/jefdewitt/Documents/education/UT-Austin/courses/ai-in-healthcare/module-6/lda_visualization.html
